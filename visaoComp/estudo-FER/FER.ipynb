# %%
pip install fer
# Out:
# Collecting ferNote: you may need to restart the kernel to use updated packages.
#
#   Using cached fer-22.4.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: mtcnn>=0.1.1 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from fer) (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from fer) (2.9.0)
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.6.0.66-cp36-abi3-win_amd64.whl (42.5 MB)
# Requirement already satisfied: requests in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from fer) (2.28.1)
# Requirement already satisfied: matplotlib in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from fer) (3.5.3)
# Requirement already satisfied: tqdm in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from fer) (4.64.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from mtcnn>=0.1.1->fer) (4.6.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (4.37.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (1.23.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from matplotlib->fer) (1.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from requests->fer) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from requests->fer) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from requests->fer) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from requests->fer) (3.3)
# Requirement already satisfied: colorama in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from tqdm->fer) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\caduc\anaconda3\envs\estudos-python-emocoes\lib\site-packages (from python-dateutil>=2.7->matplotlib->fer) (1.16.0)
# Installing collected packages: opencv-contrib-python, fer
# Successfully installed fer-22.4.0 opencv-contrib-python-4.6.0.66

# %%
from fer import FER
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_image = plt.imread("imagens/euSorrindo.jpeg")

# %%
emo_detector = FER(mtcnn=True)

# %%
captured_emotions = emo_detector.detect_emotions(test_image)
# Out:
# 1/1 [==============================] - 1s 688ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 113ms/step

# %%
print(captured_emotions)
plt.imshow(test_image)
# Out:
# [{'box': [235, 471, 471, 647], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.99, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.01}}]

# %%
print(emo_detector.top_emotion(test_image))
# Out:
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 22ms/step
# ('happy', 0.99)
